# %%
pip install cv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Users\SEC\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt
gray_image = cv2.imread(r"C:\Users\SEC\Downloads\DIPT\gray.jpg")
color_image = cv2.imread(r"C:\Users\SEC\Downloads\DIPT\color.jpg")
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Color Image",color_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       3 gray_image = cv2.imread(r"C:\Users\SEC\Downloads\DIPT\gray.jpg")
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import matplotlib.pyplot as plt 
grayscale_image=cv2.imread(r"C:\Users\SEC\Downloads\DIPT\gray.jpg")
colourscale_image=cv2.imread(r"C:\Users\SEC\Downloads\DIPT\color.jpg")
plt.imshow(gray_image)
plt.show()
plt.imshow(color_image)
plt.show()
hist = cv2.calcHist([gray_image],[0],None,[256],[0,256])
hist1 = cv2.calcHist([color_image],[1],None,[256],[0,256])
plt.figure()
plt.title("Histogram")
plt.xlabel('GrayScaleValue')
plt.ylabel('PixelCount')
plt.stem(hist)
plt.show()
plt.figure()
plt.title("Histogram")
plt.xlabel('Intensity Value')
plt.ylabel('PixelCount')
plt.stem(hist1)
plt.show()

# %%
import cv2
gray_image = cv2.imread(r"C:\Users\SEC\Downloads\DIPT\gray.jpg",0)
cv2.imshow('Grey Scale Image',gray_image)
equ = cv2.equalizeHist(gray_image)
cv2.imshow("Equalized Image",equ)
cv2.waitKey(0)
cv2.destroyAllWindows()
